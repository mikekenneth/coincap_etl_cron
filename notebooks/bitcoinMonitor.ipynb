# %%
import pandas
import requests

# %%
url = "https://api.coincap.io/v2/exchanges"
response = requests.get(url=url)
data = response.json()['data']

# %%
data
# Out:
# [{'exchangeId': 'binance',
#   'name': 'Binance',
#   'rank': '1',
#   'percentTotalVolume': '31.223640601101612153000000000000000000',
#   'volumeUsd': '16892686377.4369483314691118',
#   'tradingPairs': '929',
#   'socket': True,
#   'exchangeUrl': 'https://www.binance.com/',
#   'updated': 1651840475402},
#  {'exchangeId': 'hitbtc',
#   'name': 'HitBTC',
#   'rank': '2',
#   'percentTotalVolume': '6.789818159425247155000000000000000000',
#   'volumeUsd': '3673443151.3713419078451754',
#   'tradingPairs': '939',
#   'socket': True,
#   'exchangeUrl': 'https://hitbtc.com/',
#   'updated': 1651840479710},
#  {'exchangeId': 'gdax',
#   'name': 'Coinbase Pro',
#   'rank': '3',
#   'percentTotalVolume': '5.952657597903173154000000000000000000',
#   'volumeUsd': '3220520604.8297172649429258',
#   'tradingPairs': '349',
#   'socket': True,
#   'exchangeUrl': 'https://pro.coinbase.com/',
#   'updated': 1651840498066},
#  {'exchangeId': 'digifinex',
#   'name': 'DigiFinex',
# ...
