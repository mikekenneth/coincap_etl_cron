# %%
import pandas
import requests
from .xlib.db import WarehouseManager

# %%
url = "https://api.coincap.io/v2/exchanges"
response = requests.get(url=url)
data = response.json()['data']

# %%
data
# Out:
# [{'exchangeId': 'lbank',
#   'name': 'LBank',
#   'rank': '1',
#   'percentTotalVolume': '43.140867627459137071000000000000000000',
#   'volumeUsd': '37476515691.0469439604158353',
#   'tradingPairs': '144',
#   'socket': False,
#   'exchangeUrl': 'https://www.lbank.info',
#   'updated': 1652488911546},
#  {'exchangeId': 'binance',
#   'name': 'Binance',
#   'rank': '2',
#   'percentTotalVolume': '20.391559640282189142000000000000000000',
#   'volumeUsd': '17714168649.1613175762007732',
#   'tradingPairs': '907',
#   'socket': True,
#   'exchangeUrl': 'https://www.binance.com/',
#   'updated': 1652488883431},
#  {'exchangeId': 'gdax',
#   'name': 'Coinbase Pro',
#   'rank': '3',
#   'percentTotalVolume': '3.917205687619854168000000000000000000',
#   'volumeUsd': '3402880574.5136111774605502',
#   'tradingPairs': '346',
#   'socket': True,
#   'exchangeUrl': 'https://pro.coinbase.com/',
#   'updated': 1652488912110},
#  {'exchangeId': 'bkex',
#   'name': 'Bkex',
#   'rank': '4',
# ...
